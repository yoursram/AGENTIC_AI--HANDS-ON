# %%
# Ollama Cloud is a cloud-based extension of the Ollama platform that 
# lets you run large language models (LLMs) without needing powerful local hardware. 
# Instead of running on your own machine, the models are executed on powerful,
# datacentre-grade hardware managed by Ollama

# %%
# https://docs.ollama.com/cloud  ==> refer to this docs to know dive more

# %%
import ollama
response = ollama.generate(
    model="gpt-oss:20b-cloud",
    prompt="Why the earth is round?"
)
print(response['response'])
# Out:
# ### Why the Earth (and most planets) is round
#
# **1. Gravity pulls everything toward the center of mass.**
# - Every mass exerts a gravitational pull on every other mass.
# - If all the pieces of a body were pushed slightly outward, gravity would pull them back inward.
# - The net effect is to squeeze the body into a shape where the surface points are all at the same distance from the center – a **sphere** (more precisely, a *spheroid* for rotating bodies).
#
# **2. Hydrostatic equilibrium**
# - For a body that is fluid or has a liquid/softened interior, the shape settles into *hydrostatic equilibrium*: pressure balances gravity at every location.
# - In such a state the cross‑sectional radius is the same in all directions, again giving a sphere.
# - Planets and stars are in hydrostatic equilibrium because their interiors are partially molten or gaseous; even rocky planets can be “rounded” once they have molten up to a certain depth (e.g., during the accretion phase).
#
# ...
