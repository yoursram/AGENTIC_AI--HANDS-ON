# %%
#ollama works internally using REST API hosted locally at port 11434
# CLI  commands and Python libraries are just the wrappers around the API end-points

# %%
# Why Ollama Works With a REST API
# Ollama relies on a central REST API server
# architecture for several critical engineering and architectural
#  reasons:
# 1.Large Language Models (LLMs) require massive computing resources,
# dedicated RAM, and heavy GPU acceleration. Decoupling the heavy engine (the server) 
# from the lightweight user interface (the CLI tool or web browser)
# ensures your computer's terminal doesn't freeze or drop the model from
# memory every time you press Enter
# 2.Stateful Model Management: Standard LLMs take a long time to boot up and
# load into VRAM. Ollama uses the background API server to keep models loaded 
# or efficiently swap them out based on incoming HTTP requests, acting as an 
# automated traffic controller for your local system memory

# %%
# How It Works (The Lifecycle of a Request):


# [ User UI / CLI Tool / Code ] --> 
# [ Ollama REST API Server ]  <-- Runs in background on localhost:11434 ((1) Sends standard HTTP POST with JSON data)--->  
# [ Model Manager Engine ]    <-- Manages VRAM & switches active models ((2) Parses JSON & routes to Model Manager Queue) --->
# [ GPU / CPU Inference ]   <-- Processes mathematical weights  ((3) Feeds raw numerical tensors into hardware)

# %%
#using wrappers
import ollama

response = ollama.generate(
    model="gemma4:12b",
    prompt="Explain black hole simply" 
)
print(response['response'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 #using wrappers
#       2 import ollama
#       3
# ----> 4 response = ollama.generate(
#       5     model="gemma4:12b",
#       6     prompt="Explain black hole simply"
#       7 )
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\ollama\_client.py:281, in Client.generate(self, model, prompt, suffix, system, template, context, stream, think, logprobs, top_logprobs, raw, format, images, options, keep_alive, width, height, steps)
#     249 def generate(
#     250   self,
#     251   model: str = '',
#    (...)    269   steps: Optional[int] = None,
#     270 ) -> Union[GenerateResponse, Iterator[GenerateResponse]]:
#     271   """
#     272   Create a response using the requested model.
#     273
#    (...)    278   Returns `GenerateResponse` if `stream` is `False`, otherwise returns a `GenerateResponse` generator.
#     279   """
# --> 281   return self._request(
#     282     GenerateResponse,
#     283     'POST',
#     284     '/api/generate',
#     285     json=GenerateRequest(
#     286       model=model,
#     287       prompt=prompt,
#     288       suffix=suffix,
#     289       system=system,
#     290       template=template,
#     291       context=context,
#     292       stream=stream,
#     293       think=think,
#     294       logprobs=logprobs,
#     295       top_logprobs=top_logprobs,
#     296       raw=raw,
#     297       format=format,
#     298       images=list(_copy_images(images)) if images else None,
#     299       options=options,
#     300       keep_alive=keep_alive,
#     301       width=width,
#     302       height=height,
#     303       steps=steps,
#     304     ).model_dump(exclude_none=True),
#     305     stream=stream,
#     306   )
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\ollama\_client.py:199, in Client._request(self, cls, stream, *args, **kwargs)
#     195         yield cls(**part)
#     197   return inner()
# --> 199 return cls(**self._request_raw(*args, **kwargs).json())
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\ollama\_client.py:139, in Client._request_raw(self, *args, **kwargs)
#     137 def _request_raw(self, *args, **kwargs):
#     138   try:
# --> 139     r = self._client.request(*args, **kwargs)
#     140     r.raise_for_status()
#     141     return r
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\RAMKUMAR\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
#generate using REST API
import requests
import json

url = "http://localhost:11434/api/generate"

payload ={
    "model":"gemma4:12b",
    "prompt":"explain  black holes in simply"
}
response =  requests.post(url,json=payload)
print(response)
# Out:
# <Response [200]>

# %%
output = ""
for i in response.iter_lines():
    if i:
        data = json.loads(i.decode("utf-8"))
        if "response" in data:
            output += data["response"]
        if data.get("done"):
            break
print(output)
# Out:
# Think of a black hole as an area in space where gravity is so incredibly strong that **nothing—not even light—can escape from it.**
#
# Here is a simple breakdown of how they work:
#
# ### 1. How are they made?
# Imagine a very, very large star (much bigger than our Sun). When such a star runs out of fuel at the end of its life, it collapses under its own weight. It shrinks smaller and smaller, becoming denser and denser, until all that matter is squeezed into a tiny space. This creates a "dent" in the fabric of the universe so deep that it becomes a black hole.
#
# ### 2. Why can’t we see them?
# We call them "black" because they don't reflect or emit light. Usually, we see things because light bounces off them and hits our eyes. But since a black hole's gravity is so strong, even light gets "trapped" by it. It’s like a one-way door: things can go in, but nothing can come out.
#
# ### 3. The "Point of No Return"
# Every black hole has an invisible border called the **Event Horizon**.
# *   **Outside the line:** You can still fly away or orbit it safely.
# *   **Inside the line:** Gravity is so strong that even if you had a rocket ship moving at the speed of light, you could never escape. Once you cross this line, you are trapped forever.
#
# ### 4. What happens inside?
# At the very center of a black hole is something called the **Singularity**. This is where all the matter from the original star has been crushed into a space of zero size. Because so much stuff is packed into such a tiny space, the laws of physics as we know them start to break down.
#
# ### 5. Are they like "Space Vacuum Cleaners"?
# A common myth is that black holes go around "sucking up" everything in the galaxy. They don't! They only pull in things that get **too close.**
#
# Think of a black hole like a whirlpool in a river. If you stay far away from the whirlpool, you are perfectly safe and can sail past it. Only if you get too close to the edge does the water pull you in. Most stars and planets are far enough away from black holes to be safe.
#
# ### Summary in one sentence:
# **A black hole is a place where so much matter is packed into such a small space that gravity becomes so strong that not even light can get out.**

# %%
# import ollama 
# models = ollama.list()
# models

#        |
#        |
#        |
#       \|/

import requests

url = "http://localhost:11434/api/tags"
r = requests.get(url)
data =  r.json()
data
# Out:
# {'models': [{'name': 'gemma4:12b',
#    'model': 'gemma4:12b',
#    'modified_at': '2026-07-29T22:52:45.3314421+05:30',
#    'size': 7556508396,
#    'digest': '4eb23ef187e2c5462566d6a1d3bbbc2f1346d0b4327cbb66d58fffbcc9b2b05c',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma4',
#     'families': ['gemma4'],
#     'parameter_size': '11.9B',
#     'quantization_level': 'Q4_K_M',
#     'context_length': 262144,
#     'embedding_length': 3840},
#    'capabilities': ['completion', 'tools', 'thinking', 'vision']}]}
