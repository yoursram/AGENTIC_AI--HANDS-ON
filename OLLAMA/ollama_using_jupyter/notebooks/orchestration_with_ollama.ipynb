# %%
#
# LangChain is an open-source framework that allows you to "chain" 
# together different components to create advanced LLM applications.
# It acts as an orchestration layer that manages how data flows between the user, 
# the model (Ollama), and external tools (like Databases or Google Search).

# %%
#https://docs.langchain.com/oss/python/integrations/providers/ollama ==> refer this Docs t learn more

# %%
# !pip install langchain-ollama

import sys
# !{sys.executable} -m pip install langchain-ollama

from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="gemma4:12b",
    temperature=0,
    # other params...
)
responce = llm.invoke("why trees look in green color?")
print(responce)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: C:\Program Files\Python311\python.exe -m pip install --upgrade pip
# ...
#   Using cached langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_core-1.5.3-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached langsmith-0.10.13-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# ...
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...

# %%
# Now we can instantiate our model object and generate embeddings:

from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="gemma4:12b",
)
text = (
    "LangGraph is a library for building stateful, multi-actor applications with LLMs"
)
single_vector = embeddings.embed_query(text)
print(str(single_vector)[:100])  # Show the first 100 characters of the vector
